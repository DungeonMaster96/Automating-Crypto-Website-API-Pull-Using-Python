# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7cecd936-0b87-4bae-a245-d4f91180ae20',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
# Out:
# {'status': {'timestamp': '2024-08-06T03:10:34.804Z', 'error_code': 0, 'error_message': None, 'elapsed': 13, 'credit_count': 1, 'notice': None, 'total_count': 10035}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11626, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['Timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11626
# 1    1027      Ethereum    ETH      ethereum              9188
# 2     825   Tether USDt   USDT        tether             93569
# 3    1839           BNB    BNB           bnb              2205
# 4    5426        Solana    SOL        solana               714
# 5    3408          USDC   USDC      usd-coin             21367
# 6      52           XRP    XRP           xrp              1361
# 7      74      Dogecoin   DOGE      dogecoin              1034
# 8   11419       Toncoin    TON       toncoin               491
# 9    2010       Cardano    ADA       cardano              1220
# 10   1958          TRON    TRX          tron              1006
# 11   5994     Shiba Inu   SHIB     shiba-inu               854
# 12   5805     Avalanche   AVAX     avalanche               759
# 13   6636      Polkadot    DOT  polkadot-new               798
# ...

# %%
def api_runner():
    global df
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '7cecd936-0b87-4bae-a245-d4f91180ae20',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
#       print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data


#     df2 = pd.json_normalize(data['data'])
#     df2['Timestamp'] = pd.to_datetime('now')
#     df_append = pd.DataFrame(df2)
#     df = pd.concat([df2,df_append])

    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df


#     Use this if you want to create a csv and append data to it

    if not os.path.isfile(r'C:\Users\aryenkumar\OneDrive\Desktop\API_pull_crypto\API.csv'):
        df.to_csv(r'C:\Users\aryenkumar\OneDrive\Desktop\API_pull_crypto\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\aryenkumar\OneDrive\Desktop\API_pull_crypto\API.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11626
# 1    1027      Ethereum    ETH      ethereum              9188
# 2     825   Tether USDt   USDT        tether             93572
# 3    1839           BNB    BNB           bnb              2205
# 4    5426        Solana    SOL        solana               714
# 5    3408          USDC   USDC      usd-coin             21367
# 6      52           XRP    XRP           xrp              1361
# 7      74      Dogecoin   DOGE      dogecoin              1034
# 8   11419       Toncoin    TON       toncoin               491
# 9    2010       Cardano    ADA       cardano              1220
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               759
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               798
# ...

# %%
pd.set_option('display.float_format', lambda x:'%.5f' % x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11626
# 1    1027      Ethereum    ETH      ethereum              9188
# 2     825   Tether USDt   USDT        tether             93572
# 3    1839           BNB    BNB           bnb              2205
# 4    5426        Solana    SOL        solana               714
# 5    3408          USDC   USDC      usd-coin             21367
# 6      52           XRP    XRP           xrp              1361
# 7      74      Dogecoin   DOGE      dogecoin              1034
# 8   11419       Toncoin    TON       toncoin               491
# 9    2010       Cardano    ADA       cardano              1220
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               759
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               798
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.05157                       2.29604
# Ethereum                         -0.13558                       4.93227
# Tether USDt                       0.00752                       0.04186
# BNB                               0.03411                       6.94047
# Solana                            0.84345                       7.59198
# USDC                              0.00811                      -0.01444
# XRP                              -0.11443                       6.86152
# Dogecoin                         -0.60959                       5.88360
# Toncoin                          -0.18202                       0.69236
# Cardano                           0.28762                       4.76066
# TRON                              0.25495                       0.18269
# Avalanche                         0.31057                       7.15047
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.05157
#               quote.USD.percent_change_24h     2.29604
#               quote.USD.percent_change_7d    -16.47710
#               quote.USD.percent_change_30d    -3.77007
#               quote.USD.percent_change_60d   -21.77462
#               quote.USD.percent_change_90d   -11.63740
# Ethereum      quote.USD.percent_change_1h     -0.13558
#               quote.USD.percent_change_24h     4.93227
#               quote.USD.percent_change_7d    -24.77107
#               quote.USD.percent_change_30d   -18.13727
#               quote.USD.percent_change_60d   -34.58129
#               quote.USD.percent_change_90d   -17.75133
# Tether USDt   quote.USD.percent_change_1h      0.00752
#               quote.USD.percent_change_24h     0.04186
#               quote.USD.percent_change_7d      0.05797
#               quote.USD.percent_change_30d     0.01969
#               quote.USD.percent_change_60d     0.06390
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.05157
#              quote.USD.percent_change_24h   2.29604
#              quote.USD.percent_change_7d  -16.47710
#              quote.USD.percent_change_30d  -3.77007
#              quote.USD.percent_change_60d -21.77462
#              quote.USD.percent_change_90d -11.63740
# Ethereum     quote.USD.percent_change_1h   -0.13558
#              quote.USD.percent_change_24h   4.93227
#              quote.USD.percent_change_7d  -24.77107
#              quote.USD.percent_change_30d -18.13727
#              quote.USD.percent_change_60d -34.58129
#              quote.USD.percent_change_90d -17.75133
# Tether USDt  quote.USD.percent_change_1h    0.00752
#              quote.USD.percent_change_24h   0.04186
#              quote.USD.percent_change_7d    0.05797
#              quote.USD.percent_change_30d   0.01969
#              quote.USD.percent_change_60d   0.06390
# ...

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#             name                       level_1    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.05157
# 1        Bitcoin  quote.USD.percent_change_24h   2.29604
# 2        Bitcoin   quote.USD.percent_change_7d -16.47710
# 3        Bitcoin  quote.USD.percent_change_30d  -3.77007
# 4        Bitcoin  quote.USD.percent_change_60d -21.77462
# 5        Bitcoin  quote.USD.percent_change_90d -11.63740
# 6       Ethereum   quote.USD.percent_change_1h  -0.13558
# 7       Ethereum  quote.USD.percent_change_24h   4.93227
# 8       Ethereum   quote.USD.percent_change_7d -24.77107
# 9       Ethereum  quote.USD.percent_change_30d -18.13727
# 10      Ethereum  quote.USD.percent_change_60d -34.58129
# 11      Ethereum  quote.USD.percent_change_90d -17.75133
# 12   Tether USDt   quote.USD.percent_change_1h   0.00752
# 13   Tether USDt  quote.USD.percent_change_24h   0.04186
# 14   Tether USDt   quote.USD.percent_change_7d   0.05797
# ...

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#             name                percent_change    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.05157
# 1        Bitcoin  quote.USD.percent_change_24h   2.29604
# 2        Bitcoin   quote.USD.percent_change_7d -16.47710
# 3        Bitcoin  quote.USD.percent_change_30d  -3.77007
# 4        Bitcoin  quote.USD.percent_change_60d -21.77462
# 5        Bitcoin  quote.USD.percent_change_90d -11.63740
# 6       Ethereum   quote.USD.percent_change_1h  -0.13558
# 7       Ethereum  quote.USD.percent_change_24h   4.93227
# 8       Ethereum   quote.USD.percent_change_7d -24.77107
# 9       Ethereum  quote.USD.percent_change_30d -18.13727
# 10      Ethereum  quote.USD.percent_change_60d -34.58129
# 11      Ethereum  quote.USD.percent_change_90d -17.75133
# 12   Tether USDt   quote.USD.percent_change_1h   0.00752
# 13   Tether USDt  quote.USD.percent_change_24h   0.04186
# 14   Tether USDt   quote.USD.percent_change_7d   0.05797
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h'],['1h'])
df7
# Out:
#             name percent_change    values
# 0        Bitcoin             1h  -0.05157
# 1        Bitcoin            24h   2.29604
# 2        Bitcoin             7d -16.47710
# 3        Bitcoin            30d  -3.77007
# 4        Bitcoin            60d -21.77462
# 5        Bitcoin            90d -11.63740
# 6       Ethereum             1h  -0.13558
# 7       Ethereum            24h   4.93227
# 8       Ethereum             7d -24.77107
# 9       Ethereum            30d -18.13727
# 10      Ethereum            60d -34.58129
# 11      Ethereum            90d -17.75133
# 12   Tether USDt             1h   0.00752
# 13   Tether USDt            24h   0.04186
# 14   Tether USDt             7d   0.05797
# 15   Tether USDt            30d   0.01969
# 16   Tether USDt            60d   0.06390
# 17   Tether USDt            90d   0.05708
# 18           BNB             1h   0.03411
# 19           BNB            24h   6.94047
# 20           BNB             7d -16.20483
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# C:\Users\aryenkumar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      55651.41647 2024-08-06 09:52:49.699688

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
